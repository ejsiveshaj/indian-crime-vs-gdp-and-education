# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_gdp = pd.read_csv("../datasets folder/Districtwise_GDP_and_growth_rate_based_at_current_price_2004-05_AndhraPradesh_1.csv")
df_crime = pd.read_csv("../datasets folder/dstrIPC_1.csv")
df_education = pd.read_csv("../datasets folder/Educational_standard_of_inmates.csv")

# %%
df_crime.loc[df_crime['YEAR'] == 2005]
# Out:
#             STATE/UT     DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 2892  ANDHRA PRADESH     ADILABAD  2005     108                 48
# 2893  ANDHRA PRADESH    ANANTAPUR  2005     172                125
# 2894  ANDHRA PRADESH     CHITTOOR  2005     105                 40
# 2895  ANDHRA PRADESH     CUDDAPAH  2005      96                  0
# 2896  ANDHRA PRADESH    CYBERABAD  2005     150                 88
# ...              ...          ...   ...     ...                ...
# 3620        DELHI UT         WEST  2005      57                 55
# 3621     LAKSHADWEEP  LAKSHADWEEP  2005       1                  0
# 3622     LAKSHADWEEP        TOTAL  2005       1                  0
# 3623      PUDUCHERRY  PONDICHERRY  2005      19                 24
# 3624      PUDUCHERRY        TOTAL  2005      19                 24
#
#       CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 2892                                         13    53               0
# ...

# %%
df_gdp.head()
# Out:
#       Year       Description  Adilabad  Anantapur  Chittoor  Godavari East  \
# 0  2004-05  GDP (in Rs. Cr.)   6527.41    9286.21   9048.39       17289.90
# 1  2005-06  GDP (in Rs. Cr.)   7058.60   10047.71  10390.13       16827.15
# 2  2006-07  GDP (in Rs. Cr.)   8300.56   11252.83  11594.82       20208.88
# 3  2007-08  GDP (in Rs. Cr.)   9860.16   15937.45  14241.18       24081.05
# 4  2008-09  GDP (in Rs. Cr.)  12342.93   17713.73  15998.11       27446.05
#
#    Godavari West    Guntur  Hyderabad    Kadapa  ...     Medak  Nalgonda  \
# 0       12704.42  11878.60   16932.79   6287.94  ...   8906.57   7658.54
# 1       12791.82  14374.44   20523.91   7050.27  ...  10613.40   9047.11
# 2       14156.37  16183.82   25016.85  12448.79  ...  13879.77  10423.51
# 3       17473.10  19125.08   30038.38  14393.29  ...  14716.18  14736.51
# 4       18552.27  22550.47   35536.76  11911.79  ...  18732.63  18346.31
#
#     Nellore  Nizambad  Prakasam  Rangareddy  Srikakulam  Visakapatnam  \
# ...

# %%
df_education.head()
# Out:
#          STATE/UT  YEAR                            DEMOGRAPHIC PARTICULARS  \
# 0  ANDHRA PRADESH  2001                               Educational Standard
# 1  ANDHRA PRADESH  2001                  Educational Standard - Illiterate
# 2  ANDHRA PRADESH  2001               Educational Standard - Below Class X
# 3  ANDHRA PRADESH  2001  Educational Standard - Class X and above but b...
# 4  ANDHRA PRADESH  2001                    Educational Standard - Graduate
#
#    Male Convicts  Female Convicts  Total Convicts  Male Under trial  \
# 0           4119              102            4221              8360
# 1           1441               82            1523              3794
# 2           1729               20            1749              2833
# 3            532                0             532              1260
# 4            299                0             299               272
#
#    Female Under trial  Total Under trial  Male Detenues  Female Detenues  \
# ...

# %% [markdown]
# ## Hypothesis
# Is there any corelation with respect to crime, GDP, education.
#
# How crime changes over the year.
#
# Analyse the total no of crimes and analyse the GPD and district.

# %%
df_gdp_adilabad = df_gdp.loc[df_gdp['Description'] == 'GDP (in Rs. Cr.)']
df_crime_adilabad = df_crime.loc[df_crime['DISTRICT'] == 'ADILABAD']

# %%
total_crime = df_crime_adilabad['TOTAL IPC CRIMES'].values
total_crime = total_crime[4:]
total_crime
# Out:
# array([5033, 6122, 5685, 5300, 5312, 4955, 5121, 5710], dtype=int64)

# %%
df_gdp_adilabad
# Out:
#       Year       Description  Adilabad  Anantapur  Chittoor  Godavari East  \
# 0  2004-05  GDP (in Rs. Cr.)   6527.41    9286.21   9048.39       17289.90
# 1  2005-06  GDP (in Rs. Cr.)   7058.60   10047.71  10390.13       16827.15
# 2  2006-07  GDP (in Rs. Cr.)   8300.56   11252.83  11594.82       20208.88
# 3  2007-08  GDP (in Rs. Cr.)   9860.16   15937.45  14241.18       24081.05
# 4  2008-09  GDP (in Rs. Cr.)  12342.93   17713.73  15998.11       27446.05
# 5  2009-10  GDP (in Rs. Cr.)  13291.00   18647.00  17628.00       31687.00
# 6  2010-11  GDP (in Rs. Cr.)  16508.00   22071.00  22257.00       34374.00
# 7  2011-12  GDP (in Rs. Cr.)  17330.00   25577.00  26862.00       38600.00
# 8  2012-13  GDP (in Rs. Cr.)  19641.00   29133.00  30593.00       44254.00
#
#    Godavari West    Guntur  Hyderabad    Kadapa  ...     Medak  Nalgonda  \
# 0       12704.42  11878.60   16932.79   6287.94  ...   8906.57   7658.54
# ...

# %%
plt.scatter(x=df_gdp_adilabad.Adilabad[:len(df_gdp_adilabad)-1], y=total_crime)

# %%
df_crime_adilabad.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'YEAR', 'MURDER', 'ATTEMPT TO MURDER',
#        'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
#        'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
#        'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
#        'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
#        'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
#        'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
#        'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
#        'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
#        'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
#        'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
#        'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES'],
#       dtype='object')

# %%
crime = df_crime_adilabad['RAPE'].values
crime = crime[4:]
crime_list = ['MURDER', 'ATTEMPT TO MURDER',
       'CULPABLE HOMICIDE NOT AMOUNTING TO MURDER', 'RAPE', 'CUSTODIAL RAPE',
       'OTHER RAPE', 'KIDNAPPING & ABDUCTION',
       'KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS',
       'KIDNAPPING AND ABDUCTION OF OTHERS', 'DACOITY',
       'PREPARATION AND ASSEMBLY FOR DACOITY', 'ROBBERY', 'BURGLARY', 'THEFT',
       'AUTO THEFT', 'OTHER THEFT', 'RIOTS', 'CRIMINAL BREACH OF TRUST',
       'CHEATING', 'COUNTERFIETING', 'ARSON', 'HURT/GREVIOUS HURT',
       'DOWRY DEATHS', 'ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY',
       'INSULT TO MODESTY OF WOMEN', 'CRUELTY BY HUSBAND OR HIS RELATIVES',
       'IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES',
       'CAUSING DEATH BY NEGLIGENCE', 'OTHER IPC CRIMES', 'TOTAL IPC CRIMES']

df_adil_gdp_crime = pd.DataFrame({
    'gdp': df_gdp_adilabad.Adilabad[:len(df_gdp_adilabad)-1]
})

for crime_name in crime_list:
    crime = df_crime_adilabad[crime_name].values
    crime = crime[4:]
    crime = pd.DataFrame({
        crime_name:crime
    })
    df_adil_gdp_crime = pd.concat((df_adil_gdp_crime, crime), axis=1)

# %%
plt.imshow(df_adil_gdp_crime.corr())

# %%
correlation = df_adil_gdp_crime.corr()

# %%
type(correlation)
# Out:
# pandas.core.frame.DataFrame

# %%
df_cor_gdp = correlation['gdp']

for value in df_cor_gdp.iteritems():
    if value[1] > 0.65:
        print("positive corelation: ", value)
    if value[1] < -0.65:
        print("negative corelation: ",value)
# Out:
# positive corelation:  ('gdp', 1.0)
# positive corelation:  ('RAPE', 0.7349823157828749)
# positive corelation:  ('OTHER RAPE', 0.7349823157828749)
# positive corelation:  ('AUTO THEFT', 0.8862795384240452)
# positive corelation:  ('HURT/GREVIOUS HURT', 0.664419359128961)
# negative corelation:  ('ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY', -0.694749206073768)
# positive corelation:  ('INSULT TO MODESTY OF WOMEN', 0.7638537528541964)
# positive corelation:  ('CRUELTY BY HUSBAND OR HIS RELATIVES', 0.7839206494022228)
# positive corelation:  ('CAUSING DEATH BY NEGLIGENCE', 0.9191817031792581)
# negative corelation:  ('OTHER IPC CRIMES', -0.891898767352245)
